# %%
import os
for root, dirnames, filenames in os.walk('data'):
    print(str(root) + '#' + str(dirnames) + '#' + str(filenames))
# Out:
# data#['.ipynb_checkpoints', 'Bayes', 'neg', 'pedestrians128x64', 'pedestrians_neg', 'pos', 'test_64x128_H96', 'train']#['demo1.jpg', 'lena.jpg', 'pedestrians128x64.tar.gz', 'pedestrian_test.jpg', 'pedestrian_test2.jpg']
# data\.ipynb_checkpoints#[]#[]
# data\Bayes#['beck-s', 'BG', 'farmer-d', 'GP', 'kaminski-v', 'kitchen-l', 'lokay-m', 'SH', 'williams-w3']#['beck-s.tar.gz', 'BG.tar.gz', 'farmer-d.tar.gz', 'GP.tar.gz', 'kaminski-v.tar.gz', 'kitchen-l.tar.gz', 'lokay-m.tar.gz', 'SH.tar.gz', 'williams-w3.tar.gz']
# ...
